# %%
import pandas as pd
import sqlite3
# Out:
# Running cells with 'Python' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/praga/.local/bin/python3.14.exe -m pip install ipykernel -U --user --force-reinstall'
